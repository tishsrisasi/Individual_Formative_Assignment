# %% [markdown]
# # Data Transformation
# "Documentation for the ETL process, including data sources and transformation logic."

# %%
import pandas as pd

# %% [markdown]
# ### Loading the cleaned data source for Global Finance

# %%
df = pd.read_csv("global_finance_data_cleaned.csv")
df.head(5) #check first 5 records to see if it has loaded correctly
# Out:
#           Stock_Index         Country Currency_Code  Index_Value  \
# 0             S&P_500   United States           USD       5437.2
# 1  Shanghai_Composite           China           CNY       2891.6
# 2          Nikkei_225           Japan           JPY      36789.1
# 3                 DAX         Germany           EUR      18234.5
# 4            FTSE_100  United Kingdom           GBP       8156.3
#
#    Daily_Change_Percent  Market_Cap_Trillion_USD  GDP_Growth_Rate_Percent  \
# 0                  0.34                     51.2                      2.8
# 1                 -0.82                     12.4                      5.2
# 2                  1.24                      6.8                      0.9
# 3                  0.67                      2.9                      0.3
# 4                 -0.15                      3.1                      1.1
#
#    Inflation_Rate_Percent  Interest_Rate_Percent  Unemployment_Rate_Percent  \
# 0                     2.9                   5.50                        3.7
# 1                     0.8                   3.10                        5.2
# 2                     2.8                  -0.10                        2.4
# 3                     2.2                   4.50                        3.1
# 4                     2.0                   5.25                        4.2
#
#    ...  Current_Account_Balance_Billion_USD  FDI_Inflow_Billion_USD  \
# 0  ...                               -695.2                   456.8
# 1  ...                                382.9                   189.7
# 2  ...                                 49.7                    23.4
# 3  ...                                297.4                    67.8
# 4  ...                                -85.6                    45.2
#
#    Commodity_Index  Bond_Yield_10Y_Percent  Credit_Rating  \
# 0             1.12                    4.25            AAA
# 1             0.98                    2.15             A+
# 2             1.05                    0.89             A+
# 3             1.08                    2.31            AAA
# 4             1.06                    3.89             AA
#
#    Political_Risk_Score  Banking_Sector_Health Real_Estate_Index  \
# 0                   8.1                 Strong             145.6
# 1                   6.7               Moderate              98.7
# 2                   8.4                 Strong              89.3
# 3                   8.7                 Strong             112.4
# 4                   7.9               Moderate              97.8
#
#    Export_Growth_Percent Import_Growth_Percent
# 0                    3.2                   2.8
# 1                    8.9                   6.1
# 2                    5.1                   4.7
# 3                    2.1                   1.8
# 4                    0.9                   1.2
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Best Practice - making a dataframe copy of the original clean dataset to work with

# %%
gfd_df = df.copy() #best practice

# %% [markdown]
# ### Setting the Multi-Index (using unique values)

# %%
gfd_df = gfd_df.set_index(['Stock_Index','Currency_Code']) #multi-indexing
gfd_df.index
# Out:
# MultiIndex([(           'S&P_500', 'USD'),
#             ('Shanghai_Composite', 'CNY'),
#             (        'Nikkei_225', 'JPY'),
#             (               'DAX', 'EUR'),
#             (          'FTSE_100', 'GBP'),
#             (            'CAC_40', 'EUR'),
#             (            'Sensex', 'INR'),
#             (               'TSX', 'CAD'),
#             (           'Bovespa', 'BRL'),
#             (           'ASX_200', 'AUD'),
#             (             'KOSPI', 'KRW'),
#             (              'MOEX', 'RUB'),
#             (               'IPC', 'MXN'),
#             (          'FTSE_MIB', 'EUR'),
#             (           'IBEX_35', 'EUR'),
#             (               'AEX', 'EUR'),
#             (               'SMI', 'CHF'),
#             (     'OMX_Stockholm', 'SEK'),
#             (               'OSE', 'NOK'),
#             (           'OMXC_20', 'DKK'),
#             (               'STI', 'SGD'),
#             (         'Hang_Seng', 'HKD'),
#             (             'TAIEX', 'TWD'),
#             (               'JCI', 'IDR'),
#             (               'SET', 'THB'),
#             (              'KLCI', 'MYR'),
#             (               'PSE', 'PHP'),
#             (          'VN_Index', 'VND'),
#             (          'BIST_100', 'TRY'),
#             (               'JSE', 'ZAR'),
#             (            'EGX_30', 'EGP'),
#             (               'NSE', 'NGN'),
#             (              'IPSA', 'CLP'),
#             (            'Merval', 'ARS'),
#             (            'COLCAP', 'COP'),
#             (      'Lima_General', 'PEN'),
#             (               'ADX', 'AED'),
#             (           'Tadawul', 'SAR'),
#             (            'TA_125', 'ILS')],
#            names=['Stock_Index', 'Currency_Code'])

# %% [markdown]
# ### Best Practice - changing data types to Category where appropriate

# %%
#Best Practice - using the category types
gfd_df['Credit_Rating'] = gfd_df['Credit_Rating'].astype('category')
gfd_df['Banking_Sector_Health'] = gfd_df['Banking_Sector_Health'].astype('category')
gfd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 39 entries, ('S&P_500', 'USD') to ('TA_125', 'ILS')
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Index_Value                          39 non-null     float64
#  2   Daily_Change_Percent                 39 non-null     float64
#  3   Market_Cap_Trillion_USD              39 non-null     float64
#  4   GDP_Growth_Rate_Percent              39 non-null     float64
#  5   Inflation_Rate_Percent               39 non-null     float64
#  6   Interest_Rate_Percent                39 non-null     float64
#  7   Unemployment_Rate_Percent            39 non-null     float64
#  8   Exchange_Rate_USD                    39 non-null     float64
#  9   Currency_Change_YTD_Percent          39 non-null     float64
#  10  Government_Debt_GDP_Percent          39 non-null     float64
#  11  Current_Account_Balance_Billion_USD  39 non-null     float64
#  12  FDI_Inflow_Billion_USD               39 non-null     float64
#  13  Commodity_Index                      39 non-null     float64
#  14  Bond_Yield_10Y_Percent               39 non-null     float64
#  15  Credit_Rating                        39 non-null     category
#  16  Political_Risk_Score                 39 non-null     float64
#  17  Banking_Sector_Health                39 non-null     category
#  18  Real_Estate_Index                    39 non-null     float64
#  19  Export_Growth_Percent                39 non-null     float64
#  20  Import_Growth_Percent                39 non-null     float64
# dtypes: category(2), float64(18), object(1)
# memory usage: 9.5+ KB

# %% [markdown]
# ## Feature Engineering & Transformation Logic:

# %% [markdown]
# ### Defining the Function for new Feature: Country_Group

# %%
def find_country_group(country):

    country_groups = {
    
    ('United States','Japan','Germany','United Kingdom','France','Canada','Italy'):'G7',
    ('China','India','Brazil','Russia','Hong Kong','Indonesia','South Africa','Egypt','UAE','Saudi Arabia'):'BRICS',
    ('Australia','South Korea','Mexico','Switzerland','Turkey','Argentina'):'G20',
    ('Nigeria'):'Africa',
    ('Singapore','Taiwan','Thailand','Malaysia','Philippines','Vietnam'):'Asia',
    ('Spain','Netherlands','Sweden','Norway','Denmark'):'Europe',
    ('Israel'):'Middle East',
    ('Chile','Colombia','Peru'):'South America'
    
}
    for k_country, v_group in country_groups.items():
      if country in k_country:
          return v_group

# %% [markdown]
# ### Applying the function to the dataframe using Lambda - then changing the data type of new feature to a category

# %%
gfd_df['Country_Group_Derived'] = gfd_df.apply(lambda row: find_country_group(row['Country']), axis=1)
gfd_df['Country_Group_Derived'] = gfd_df['Country_Group_Derived'].astype('category') #Best Practice - using the category types
gfd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 39 entries, ('S&P_500', 'USD') to ('TA_125', 'ILS')
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Index_Value                          39 non-null     float64
#  2   Daily_Change_Percent                 39 non-null     float64
#  3   Market_Cap_Trillion_USD              39 non-null     float64
#  4   GDP_Growth_Rate_Percent              39 non-null     float64
#  5   Inflation_Rate_Percent               39 non-null     float64
#  6   Interest_Rate_Percent                39 non-null     float64
#  7   Unemployment_Rate_Percent            39 non-null     float64
#  8   Exchange_Rate_USD                    39 non-null     float64
#  9   Currency_Change_YTD_Percent          39 non-null     float64
#  10  Government_Debt_GDP_Percent          39 non-null     float64
#  11  Current_Account_Balance_Billion_USD  39 non-null     float64
#  12  FDI_Inflow_Billion_USD               39 non-null     float64
#  13  Commodity_Index                      39 non-null     float64
#  14  Bond_Yield_10Y_Percent               39 non-null     float64
#  15  Credit_Rating                        39 non-null     category
#  16  Political_Risk_Score                 39 non-null     float64
#  17  Banking_Sector_Health                39 non-null     category
#  18  Real_Estate_Index                    39 non-null     float64
#  19  Export_Growth_Percent                39 non-null     float64
#  20  Import_Growth_Percent                39 non-null     float64
#  21  Country_Group_Derived                39 non-null     category
# dtypes: category(3), float64(18), object(1)
# memory usage: 9.9+ KB

# %% [markdown]
# ### Defining the Function for 2 new Features: Credit Grade Derived and Credit Grade Classification Derived
# Using 1 function to derive 2 values, depending if there is a second value passed to it (2nd value defaults to 0)

# %%
def snpCRlookup(credit_rating,info=0):
        
        ratings = {
            
            ('AAA'):['Prime', 'Investment'],
            ('AA+','AA','AA-'):['High Grade', 'Investment'],
            ('A+','A','A-'):['Upper Medium Grade', 'Investment'],
            ('BBB+','BBB','BBB-'):['Lower Medium Grade','Investment'],
            ('BB+','BB','BB-'):['Speculative', 'Non-Investment/Speculative'],
            ('B+','B','B-'):['Highly Speculative','Non-Investment/Speculative'],
            ('CCC+','CCC','CCC-'):['Substantial Risk','Non-Investment/Speculative'],
            ('CC'):['Extremely Speculative','Non-Investment/Speculative'],
            ('C'):['Near Default','Non-Investment/Speculative'],
            ('D'):['Default','Non-Investment/Speculative'],
            ('R'):['Regulatory Supervision','Special Classification'],
            ('SD'):['Speculative Default','Special Classification'],
            ('NR'):['Not Rated','Special Classification']
        
        }
    
        for key, value in ratings.items():
            
                if credit_rating in key:
                    
                    if info == 0:
                        return value[0]
                        
                    else:
                        return value[1]

# %% [markdown]
# ### Applying the function to the dataframe using Lambda - then changing the data type of new features to a category

# %%
gfd_df['Credit_Grade_Derived'] = gfd_df.apply(lambda row: snpCRlookup(row['Credit_Rating']), axis=1)
gfd_df['CR_Grade_Classification_Derived'] = gfd_df.apply(lambda row: snpCRlookup(row['Credit_Rating'],1), axis=1)
gfd_df['Credit_Grade_Derived'] = gfd_df['Credit_Grade_Derived'].astype('category')
gfd_df['CR_Grade_Classification_Derived'] = gfd_df['CR_Grade_Classification_Derived'].astype('category')
gfd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 39 entries, ('S&P_500', 'USD') to ('TA_125', 'ILS')
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Index_Value                          39 non-null     float64
#  2   Daily_Change_Percent                 39 non-null     float64
#  3   Market_Cap_Trillion_USD              39 non-null     float64
#  4   GDP_Growth_Rate_Percent              39 non-null     float64
#  5   Inflation_Rate_Percent               39 non-null     float64
#  6   Interest_Rate_Percent                39 non-null     float64
#  7   Unemployment_Rate_Percent            39 non-null     float64
#  8   Exchange_Rate_USD                    39 non-null     float64
#  9   Currency_Change_YTD_Percent          39 non-null     float64
#  10  Government_Debt_GDP_Percent          39 non-null     float64
#  11  Current_Account_Balance_Billion_USD  39 non-null     float64
#  12  FDI_Inflow_Billion_USD               39 non-null     float64
#  13  Commodity_Index                      39 non-null     float64
#  14  Bond_Yield_10Y_Percent               39 non-null     float64
#  15  Credit_Rating                        39 non-null     category
#  16  Political_Risk_Score                 39 non-null     float64
#  17  Banking_Sector_Health                39 non-null     category
#  18  Real_Estate_Index                    39 non-null     float64
#  19  Export_Growth_Percent                39 non-null     float64
#  20  Import_Growth_Percent                39 non-null     float64
#  21  Country_Group_Derived                39 non-null     category
#  22  Credit_Grade_Derived                 39 non-null     category
#  23  CR_Grade_Classification_Derived      39 non-null     category
# dtypes: category(5), float64(18), object(1)
# memory usage: 10.4+ KB

# %% [markdown]
# ### Defining the Function for new Feature: Banking Sector Health Number (Derived)
# Note to self: Will do this using pipes when considering Machine Learning

# %%
def convert_bankingsechealth_tonum(banking_sector_health):

    bsh_mappings = {
    
    'Strong': 1,
    'Moderate': 2,
    'Weak': 3,
    
}
    return bsh_mappings[banking_sector_health]

# %% [markdown]
# ### Applying the function to the dataframe using Lambda - then changing the data type of new feature to a category

# %%
gfd_df['Banking_Sector_Health_Num_Derived'] = gfd_df.apply(lambda row: convert_bankingsechealth_tonum(row['Banking_Sector_Health']), axis=1)
gfd_df['Banking_Sector_Health_Num_Derived'] = gfd_df['Banking_Sector_Health_Num_Derived'].astype('category')
gfd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 39 entries, ('S&P_500', 'USD') to ('TA_125', 'ILS')
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Index_Value                          39 non-null     float64
#  2   Daily_Change_Percent                 39 non-null     float64
#  3   Market_Cap_Trillion_USD              39 non-null     float64
#  4   GDP_Growth_Rate_Percent              39 non-null     float64
#  5   Inflation_Rate_Percent               39 non-null     float64
#  6   Interest_Rate_Percent                39 non-null     float64
#  7   Unemployment_Rate_Percent            39 non-null     float64
#  8   Exchange_Rate_USD                    39 non-null     float64
#  9   Currency_Change_YTD_Percent          39 non-null     float64
#  10  Government_Debt_GDP_Percent          39 non-null     float64
#  11  Current_Account_Balance_Billion_USD  39 non-null     float64
#  12  FDI_Inflow_Billion_USD               39 non-null     float64
#  13  Commodity_Index                      39 non-null     float64
#  14  Bond_Yield_10Y_Percent               39 non-null     float64
#  15  Credit_Rating                        39 non-null     category
#  16  Political_Risk_Score                 39 non-null     float64
#  17  Banking_Sector_Health                39 non-null     category
#  18  Real_Estate_Index                    39 non-null     float64
#  19  Export_Growth_Percent                39 non-null     float64
#  20  Import_Growth_Percent                39 non-null     float64
#  21  Country_Group_Derived                39 non-null     category
#  22  Credit_Grade_Derived                 39 non-null     category
#  23  CR_Grade_Classification_Derived      39 non-null     category
#  24  Banking_Sector_Health_Num_Derived    39 non-null     category
# dtypes: category(6), float64(18), object(1)
# memory usage: 10.6+ KB

# %% [markdown]
# ### Checking the new Banking Sector Health numbers are correct

# %%
gfd_df[['Banking_Sector_Health',
        'Banking_Sector_Health_Num_Derived']]
# Out:
#                                  Banking_Sector_Health  \
# Stock_Index        Currency_Code
# S&P_500            USD                          Strong
# Shanghai_Composite CNY                        Moderate
# Nikkei_225         JPY                          Strong
# DAX                EUR                          Strong
# FTSE_100           GBP                        Moderate
# CAC_40             EUR                        Moderate
# Sensex             INR                        Moderate
# TSX                CAD                          Strong
# Bovespa            BRL                            Weak
# ASX_200            AUD                          Strong
# KOSPI              KRW                          Strong
# MOEX               RUB                            Weak
# IPC                MXN                        Moderate
# FTSE_MIB           EUR                        Moderate
# IBEX_35            EUR                        Moderate
# AEX                EUR                          Strong
# SMI                CHF                          Strong
# OMX_Stockholm      SEK                          Strong
# OSE                NOK                          Strong
# OMXC_20            DKK                          Strong
# STI                SGD                          Strong
# Hang_Seng          HKD                        Moderate
# TAIEX              TWD                          Strong
# JCI                IDR                        Moderate
# SET                THB                        Moderate
# KLCI               MYR                        Moderate
# PSE                PHP                        Moderate
# VN_Index           VND                        Moderate
# BIST_100           TRY                            Weak
# JSE                ZAR                            Weak
# EGX_30             EGP                            Weak
# NSE                NGN                            Weak
# IPSA               CLP                        Moderate
# Merval             ARS                            Weak
# COLCAP             COP                        Moderate
# Lima_General       PEN                        Moderate
# ADX                AED                          Strong
# Tadawul            SAR                        Moderate
# TA_125             ILS                        Moderate
#
#                                  Banking_Sector_Health_Num_Derived
# Stock_Index        Currency_Code
# S&P_500            USD                                           1
# Shanghai_Composite CNY                                           2
# Nikkei_225         JPY                                           1
# DAX                EUR                                           1
# FTSE_100           GBP                                           2
# CAC_40             EUR                                           2
# Sensex             INR                                           2
# TSX                CAD                                           1
# Bovespa            BRL                                           3
# ASX_200            AUD                                           1
# KOSPI              KRW                                           1
# MOEX               RUB                                           3
# IPC                MXN                                           2
# FTSE_MIB           EUR                                           2
# IBEX_35            EUR                                           2
# AEX                EUR                                           1
# SMI                CHF                                           1
# OMX_Stockholm      SEK                                           1
# OSE                NOK                                           1
# OMXC_20            DKK                                           1
# STI                SGD                                           1
# Hang_Seng          HKD                                           2
# TAIEX              TWD                                           1
# JCI                IDR                                           2
# SET                THB                                           2
# KLCI               MYR                                           2
# PSE                PHP                                           2
# VN_Index           VND                                           2
# BIST_100           TRY                                           3
# JSE                ZAR                                           3
# EGX_30             EGP                                           3
# NSE                NGN                                           3
# IPSA               CLP                                           2
# Merval             ARS                                           3
# COLCAP             COP                                           2
# Lima_General       PEN                                           2
# ADX                AED                                           1
# Tadawul            SAR                                           2
# TA_125             ILS                                           2

# %% [markdown]
# ### Building in a suitable proxy for country's GDP value and 5 new ratio features missing from the original dataset
# 1. A GDP Proxy (USD Billions) created by converting Market Capital (USD Trillion) into USD Billion
# 2. Current Account to GDP Ratio (%age)
# 3. Export-to-Import Growth Ratio
# 4. FDI-to-GDP Ratio (%age)
# 5. Interest Rate Spread
# 6. Unemployment-to-GDP Growth Ratio (%age)

# %%
#A GDP Proxy (USD Billions) created by converting Market Capital (USD Trillion) into USD Billion
gfd_df['GDP_Proxy_Billion_USD'] = gfd_df['Market_Cap_Trillion_USD'] * 1000

#Current Account to GDP Ratio (%age)
gfd_df['Current_Account_To_GDP_Ratio'] = (gfd_df['Current_Account_Balance_Billion_USD']/gfd_df['GDP_Proxy_Billion_USD'])*100

#Export-to-Import Growth Ratio
gfd_df['Export_To_Import_Growth_Ratio'] = gfd_df['Export_Growth_Percent']/(gfd_df['Import_Growth_Percent'])

#FDI-to-GDP Ratio (%age)
gfd_df['FDI_To_GDP_Ratio'] = (gfd_df['FDI_Inflow_Billion_USD']/gfd_df['GDP_Proxy_Billion_USD'])*100

#Interest Rate Spread
gfd_df['Interest_Rate_Spread'] = gfd_df['Interest_Rate_Percent']-gfd_df['Bond_Yield_10Y_Percent']

#Unemployment-to-GDP Growth Ratio
gfd_df['Unemployment_To_GDP_Growth_Ratio'] = (gfd_df['Unemployment_Rate_Percent']/gfd_df['GDP_Proxy_Billion_USD'])*100

# %%
gfd_df.head(3)
# Out:
#                                         Country  Index_Value  \
# Stock_Index        Currency_Code
# S&P_500            USD            United States       5437.2
# Shanghai_Composite CNY                    China       2891.6
# Nikkei_225         JPY                    Japan      36789.1
#
#                                   Daily_Change_Percent  \
# Stock_Index        Currency_Code
# S&P_500            USD                            0.34
# Shanghai_Composite CNY                           -0.82
# Nikkei_225         JPY                            1.24
#
#                                   Market_Cap_Trillion_USD  \
# Stock_Index        Currency_Code
# S&P_500            USD                               51.2
# Shanghai_Composite CNY                               12.4
# Nikkei_225         JPY                                6.8
#
#                                   GDP_Growth_Rate_Percent  \
# Stock_Index        Currency_Code
# S&P_500            USD                                2.8
# Shanghai_Composite CNY                                5.2
# Nikkei_225         JPY                                0.9
#
#                                   Inflation_Rate_Percent  \
# Stock_Index        Currency_Code
# S&P_500            USD                               2.9
# Shanghai_Composite CNY                               0.8
# Nikkei_225         JPY                               2.8
#
#                                   Interest_Rate_Percent  \
# Stock_Index        Currency_Code
# S&P_500            USD                              5.5
# Shanghai_Composite CNY                              3.1
# Nikkei_225         JPY                             -0.1
#
#                                   Unemployment_Rate_Percent  \
# Stock_Index        Currency_Code
# S&P_500            USD                                  3.7
# Shanghai_Composite CNY                                  5.2
# Nikkei_225         JPY                                  2.4
#
#                                   Exchange_Rate_USD  \
# Stock_Index        Currency_Code
# S&P_500            USD                         1.00
# Shanghai_Composite CNY                         7.28
# Nikkei_225         JPY                       147.20
#
#                                   Currency_Change_YTD_Percent  ...  \
# Stock_Index        Currency_Code                               ...
# S&P_500            USD                                    0.0  ...
# Shanghai_Composite CNY                                    2.3  ...
# Nikkei_225         JPY                                   -8.9  ...
#
#                                   Country_Group_Derived  Credit_Grade_Derived  \
# Stock_Index        Currency_Code
# S&P_500            USD                               G7                 Prime
# Shanghai_Composite CNY                            BRICS    Upper Medium Grade
# Nikkei_225         JPY                               G7    Upper Medium Grade
#
#                                   CR_Grade_Classification_Derived  \
# Stock_Index        Currency_Code
# S&P_500            USD                                 Investment
# Shanghai_Composite CNY                                 Investment
# Nikkei_225         JPY                                 Investment
#
#                                   Banking_Sector_Health_Num_Derived  \
# Stock_Index        Currency_Code
# S&P_500            USD                                            1
# Shanghai_Composite CNY                                            2
# Nikkei_225         JPY                                            1
#
#                                   GDP_Proxy_Billion_USD  \
# Stock_Index        Currency_Code
# S&P_500            USD                          51200.0
# Shanghai_Composite CNY                          12400.0
# Nikkei_225         JPY                           6800.0
#
#                                  Current_Account_To_GDP_Ratio  \
# Stock_Index        Currency_Code
# S&P_500            USD                              -1.357813
# Shanghai_Composite CNY                               3.087903
# Nikkei_225         JPY                               0.730882
#
#                                   Export_To_Import_Growth_Ratio  \
# Stock_Index        Currency_Code
# S&P_500            USD                                 1.142857
# Shanghai_Composite CNY                                 1.459016
# Nikkei_225         JPY                                 1.085106
#
#                                  FDI_To_GDP_Ratio  Interest_Rate_Spread  \
# Stock_Index        Currency_Code
# S&P_500            USD                   0.892188                  1.25
# Shanghai_Composite CNY                   1.529839                  0.95
# Nikkei_225         JPY                   0.344118                 -0.99
#
#                                   Unemployment_To_GDP_Growth_Ratio
# Stock_Index        Currency_Code
# S&P_500            USD                                    0.007227
# Shanghai_Composite CNY                                    0.041935
# Nikkei_225         JPY                                    0.035294
#
# [3 rows x 31 columns]

# %%
gfd_df.info() #a final check to see if all the new features have been added to the dataframe before saving as new file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 39 entries, ('S&P_500', 'USD') to ('TA_125', 'ILS')
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Index_Value                          39 non-null     float64
#  2   Daily_Change_Percent                 39 non-null     float64
#  3   Market_Cap_Trillion_USD              39 non-null     float64
#  4   GDP_Growth_Rate_Percent              39 non-null     float64
#  5   Inflation_Rate_Percent               39 non-null     float64
#  6   Interest_Rate_Percent                39 non-null     float64
#  7   Unemployment_Rate_Percent            39 non-null     float64
#  8   Exchange_Rate_USD                    39 non-null     float64
#  9   Currency_Change_YTD_Percent          39 non-null     float64
#  10  Government_Debt_GDP_Percent          39 non-null     float64
#  11  Current_Account_Balance_Billion_USD  39 non-null     float64
#  12  FDI_Inflow_Billion_USD               39 non-null     float64
#  13  Commodity_Index                      39 non-null     float64
#  14  Bond_Yield_10Y_Percent               39 non-null     float64
#  15  Credit_Rating                        39 non-null     category
#  16  Political_Risk_Score                 39 non-null     float64
#  17  Banking_Sector_Health                39 non-null     category
#  18  Real_Estate_Index                    39 non-null     float64
#  19  Export_Growth_Percent                39 non-null     float64
#  20  Import_Growth_Percent                39 non-null     float64
#  21  Country_Group_Derived                39 non-null     category
#  22  Credit_Grade_Derived                 39 non-null     category
#  23  CR_Grade_Classification_Derived      39 non-null     category
#  24  Banking_Sector_Health_Num_Derived    39 non-null     category
#  25  GDP_Proxy_Billion_USD                39 non-null     float64
#  26  Current_Account_To_GDP_Ratio         39 non-null     float64
#  27  Export_To_Import_Growth_Ratio        39 non-null     float64
#  28  FDI_To_GDP_Ratio                     39 non-null     float64
#  29  Interest_Rate_Spread                 39 non-null     float64
#  30  Unemployment_To_GDP_Growth_Ratio     39 non-null     float64
# dtypes: category(6), float64(24), object(1)
# memory usage: 12.4+ KB

# %% [markdown]
# ### Finaly, saving the dataframe again (with indexed columns) for further analysis

# %%
gfd_df.to_csv('global_finance_data_FeatureEng.csv', index=True)
