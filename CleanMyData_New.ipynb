# %% [markdown]
# # Extract, Loading & Cleaning the Data
# "All data is logically cleaned, preprocessed and  transformed into the correct format for analysis"

# %%
import pandas as pd

# %% [markdown]
# ### Loading the Raw 'Global Finance Data' dataset from my GitHub portal (for easier access)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/tishsrisasi/my-first-project/refs/heads/main/Global%20finance%20data.csv")
df.head(5) #checking first 5 records to see if data loaded successfully.
# Out:
#           Country        Date         Stock_Index  Index_Value  \
# 0   United States  2024-08-15             S&P_500       5437.2
# 1           China  2024-08-15  Shanghai_Composite       2891.6
# 2           Japan  2024-08-15          Nikkei_225      36789.1
# 3         Germany  2024-08-15                 DAX      18234.5
# 4  United Kingdom  2024-08-15            FTSE_100       8156.3
#
#    Daily_Change_Percent  Market_Cap_Trillion_USD  GDP_Growth_Rate_Percent  \
# 0                  0.34                     51.2                      2.8
# 1                 -0.82                     12.4                      5.2
# 2                  1.24                      6.8                      0.9
# 3                  0.67                      2.9                      0.3
# 4                 -0.15                      3.1                      1.1
#
#    Inflation_Rate_Percent  Interest_Rate_Percent  Unemployment_Rate_Percent  \
# 0                     2.9                   5.50                        3.7
# 1                     0.8                   3.10                        5.2
# 2                     2.8                  -0.10                        2.4
# 3                     2.2                   4.50                        3.1
# 4                     2.0                   5.25                        4.2
#
#    ... Commodity_Index  Oil_Price_USD_Barrel  Gold_Price_USD_Ounce  \
# 0  ...            1.12                 77.85                2487.5
# 1  ...            0.98                 77.85                2487.5
# 2  ...            1.05                 77.85                2487.5
# 3  ...            1.08                 77.85                2487.5
# 4  ...            1.06                 77.85                2487.5
#
#    Bond_Yield_10Y_Percent  Credit_Rating  Political_Risk_Score  \
# 0                    4.25            AAA                   8.1
# 1                    2.15             A+                   6.7
# 2                    0.89             A+                   8.4
# 3                    2.31            AAA                   8.7
# 4                    3.89             AA                   7.9
#
#    Banking_Sector_Health  Real_Estate_Index  Export_Growth_Percent  \
# 0                 Strong              145.6                    3.2
# 1               Moderate               98.7                    8.9
# 2                 Strong               89.3                    5.1
# 3                 Strong              112.4                    2.1
# 4               Moderate               97.8                    0.9
#
#    Import_Growth_Percent
# 0                    2.8
# 1                    6.1
# 2                    4.7
# 3                    1.8
# 4                    1.2
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Creating a copy of the dataframe to use (application of Best Practice)

# %%
gfd_df = df.copy() #Best Practice

# %%
gfd_df.head() #checking again using new dataframe copy
# Out:
#           Country        Date         Stock_Index  Index_Value  \
# 0   United States  2024-08-15             S&P_500       5437.2
# 1           China  2024-08-15  Shanghai_Composite       2891.6
# 2           Japan  2024-08-15          Nikkei_225      36789.1
# 3         Germany  2024-08-15                 DAX      18234.5
# 4  United Kingdom  2024-08-15            FTSE_100       8156.3
#
#    Daily_Change_Percent  Market_Cap_Trillion_USD  GDP_Growth_Rate_Percent  \
# 0                  0.34                     51.2                      2.8
# 1                 -0.82                     12.4                      5.2
# 2                  1.24                      6.8                      0.9
# 3                  0.67                      2.9                      0.3
# 4                 -0.15                      3.1                      1.1
#
#    Inflation_Rate_Percent  Interest_Rate_Percent  Unemployment_Rate_Percent  \
# 0                     2.9                   5.50                        3.7
# 1                     0.8                   3.10                        5.2
# 2                     2.8                  -0.10                        2.4
# 3                     2.2                   4.50                        3.1
# 4                     2.0                   5.25                        4.2
#
#    ... Commodity_Index  Oil_Price_USD_Barrel  Gold_Price_USD_Ounce  \
# 0  ...            1.12                 77.85                2487.5
# 1  ...            0.98                 77.85                2487.5
# 2  ...            1.05                 77.85                2487.5
# 3  ...            1.08                 77.85                2487.5
# 4  ...            1.06                 77.85                2487.5
#
#    Bond_Yield_10Y_Percent  Credit_Rating  Political_Risk_Score  \
# 0                    4.25            AAA                   8.1
# 1                    2.15             A+                   6.7
# 2                    0.89             A+                   8.4
# 3                    2.31            AAA                   8.7
# 4                    3.89             AA                   7.9
#
#    Banking_Sector_Health  Real_Estate_Index  Export_Growth_Percent  \
# 0                 Strong              145.6                    3.2
# 1               Moderate               98.7                    8.9
# 2                 Strong               89.3                    5.1
# 3                 Strong              112.4                    2.1
# 4               Moderate               97.8                    0.9
#
#    Import_Growth_Percent
# 0                    2.8
# 1                    6.1
# 2                    4.7
# 3                    1.8
# 4                    1.2
#
# [5 rows x 26 columns]

# %%
gfd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Date                                 39 non-null     object
#  2   Stock_Index                          39 non-null     object
#  3   Index_Value                          39 non-null     float64
#  4   Daily_Change_Percent                 39 non-null     float64
#  5   Market_Cap_Trillion_USD              39 non-null     float64
#  6   GDP_Growth_Rate_Percent              39 non-null     float64
#  7   Inflation_Rate_Percent               39 non-null     float64
#  8   Interest_Rate_Percent                39 non-null     float64
#  9   Unemployment_Rate_Percent            39 non-null     float64
#  10  Currency_Code                        39 non-null     object
#  11  Exchange_Rate_USD                    39 non-null     float64
#  12  Currency_Change_YTD_Percent          39 non-null     float64
#  13  Government_Debt_GDP_Percent          39 non-null     float64
#  14  Current_Account_Balance_Billion_USD  39 non-null     float64
#  15  FDI_Inflow_Billion_USD               39 non-null     float64
#  16  Commodity_Index                      39 non-null     float64
#  17  Oil_Price_USD_Barrel                 39 non-null     float64
#  18  Gold_Price_USD_Ounce                 39 non-null     float64
#  19  Bond_Yield_10Y_Percent               39 non-null     float64
#  20  Credit_Rating                        39 non-null     object
#  21  Political_Risk_Score                 39 non-null     float64
#  22  Banking_Sector_Health                39 non-null     object
#  23  Real_Estate_Index                    39 non-null     float64
#  24  Export_Growth_Percent                39 non-null     float64
#  25  Import_Growth_Percent                39 non-null     float64
# dtypes: float64(20), object(6)
# memory usage: 8.1+ KB

# %%
#Best Practice - using the category types for the below
gfd_df['Credit_Rating'] = gfd_df['Credit_Rating'].astype('category')
gfd_df['Banking_Sector_Health'] = gfd_df['Banking_Sector_Health'].astype('category')
gfd_df.info() #confirm that category data types are in place
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              39 non-null     object
#  1   Date                                 39 non-null     object
#  2   Stock_Index                          39 non-null     object
#  3   Index_Value                          39 non-null     float64
#  4   Daily_Change_Percent                 39 non-null     float64
#  5   Market_Cap_Trillion_USD              39 non-null     float64
#  6   GDP_Growth_Rate_Percent              39 non-null     float64
#  7   Inflation_Rate_Percent               39 non-null     float64
#  8   Interest_Rate_Percent                39 non-null     float64
#  9   Unemployment_Rate_Percent            39 non-null     float64
#  10  Currency_Code                        39 non-null     object
#  11  Exchange_Rate_USD                    39 non-null     float64
#  12  Currency_Change_YTD_Percent          39 non-null     float64
#  13  Government_Debt_GDP_Percent          39 non-null     float64
#  14  Current_Account_Balance_Billion_USD  39 non-null     float64
#  15  FDI_Inflow_Billion_USD               39 non-null     float64
#  16  Commodity_Index                      39 non-null     float64
#  17  Oil_Price_USD_Barrel                 39 non-null     float64
#  18  Gold_Price_USD_Ounce                 39 non-null     float64
#  19  Bond_Yield_10Y_Percent               39 non-null     float64
#  20  Credit_Rating                        39 non-null     category
#  21  Political_Risk_Score                 39 non-null     float64
#  22  Banking_Sector_Health                39 non-null     category
#  23  Real_Estate_Index                    39 non-null     float64
#  24  Export_Growth_Percent                39 non-null     float64
#  25  Import_Growth_Percent                39 non-null     float64
# dtypes: category(2), float64(20), object(4)
# memory usage: 8.3+ KB

# %%
gfd_df.index
# Out:
# RangeIndex(start=0, stop=39, step=1)

# %%
gfd_df = gfd_df.set_index(['Stock_Index', 'Country', 'Currency_Code']) #multi-indexing
gfd_df.index
# Out:
# MultiIndex([(           'S&P_500',  'United States', 'USD'),
#             ('Shanghai_Composite',          'China', 'CNY'),
#             (        'Nikkei_225',          'Japan', 'JPY'),
#             (               'DAX',        'Germany', 'EUR'),
#             (          'FTSE_100', 'United Kingdom', 'GBP'),
#             (            'CAC_40',         'France', 'EUR'),
#             (            'Sensex',          'India', 'INR'),
#             (               'TSX',         'Canada', 'CAD'),
#             (           'Bovespa',         'Brazil', 'BRL'),
#             (           'ASX_200',      'Australia', 'AUD'),
#             (             'KOSPI',    'South Korea', 'KRW'),
#             (              'MOEX',         'Russia', 'RUB'),
#             (               'IPC',         'Mexico', 'MXN'),
#             (          'FTSE_MIB',          'Italy', 'EUR'),
#             (           'IBEX_35',          'Spain', 'EUR'),
#             (               'AEX',    'Netherlands', 'EUR'),
#             (               'SMI',    'Switzerland', 'CHF'),
#             (     'OMX_Stockholm',         'Sweden', 'SEK'),
#             (               'OSE',         'Norway', 'NOK'),
#             (           'OMXC_20',        'Denmark', 'DKK'),
#             (               'STI',      'Singapore', 'SGD'),
#             (         'Hang_Seng',      'Hong Kong', 'HKD'),
#             (             'TAIEX',         'Taiwan', 'TWD'),
#             (               'JCI',      'Indonesia', 'IDR'),
#             (               'SET',       'Thailand', 'THB'),
#             (              'KLCI',       'Malaysia', 'MYR'),
#             (               'PSE',    'Philippines', 'PHP'),
#             (          'VN_Index',        'Vietnam', 'VND'),
#             (          'BIST_100',         'Turkey', 'TRY'),
#             (               'JSE',   'South Africa', 'ZAR'),
#             (            'EGX_30',          'Egypt', 'EGP'),
#             (               'NSE',        'Nigeria', 'NGN'),
#             (              'IPSA',          'Chile', 'CLP'),
#             (            'Merval',      'Argentina', 'ARS'),
#             (            'COLCAP',       'Colombia', 'COP'),
#             (      'Lima_General',           'Peru', 'PEN'),
#             (               'ADX',            'UAE', 'AED'),
#             (           'Tadawul',   'Saudi Arabia', 'SAR'),
#             (            'TA_125',         'Israel', 'ILS')],
#            names=['Stock_Index', 'Country', 'Currency_Code'])

# %%
gfd_df.head() #checking the new indexes are in place
# Out:
#                                                        Date  Index_Value  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD            2024-08-15       5437.2
# Shanghai_Composite China          CNY            2024-08-15       2891.6
# Nikkei_225         Japan          JPY            2024-08-15      36789.1
# DAX                Germany        EUR            2024-08-15      18234.5
# FTSE_100           United Kingdom GBP            2024-08-15       8156.3
#
#                                                  Daily_Change_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                            0.34
# Shanghai_Composite China          CNY                           -0.82
# Nikkei_225         Japan          JPY                            1.24
# DAX                Germany        EUR                            0.67
# FTSE_100           United Kingdom GBP                           -0.15
#
#                                                  Market_Cap_Trillion_USD  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                               51.2
# Shanghai_Composite China          CNY                               12.4
# Nikkei_225         Japan          JPY                                6.8
# DAX                Germany        EUR                                2.9
# FTSE_100           United Kingdom GBP                                3.1
#
#                                                  GDP_Growth_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                2.8
# Shanghai_Composite China          CNY                                5.2
# Nikkei_225         Japan          JPY                                0.9
# DAX                Germany        EUR                                0.3
# FTSE_100           United Kingdom GBP                                1.1
#
#                                                  Inflation_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                               2.9
# Shanghai_Composite China          CNY                               0.8
# Nikkei_225         Japan          JPY                               2.8
# DAX                Germany        EUR                               2.2
# FTSE_100           United Kingdom GBP                               2.0
#
#                                                  Interest_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             5.50
# Shanghai_Composite China          CNY                             3.10
# Nikkei_225         Japan          JPY                            -0.10
# DAX                Germany        EUR                             4.50
# FTSE_100           United Kingdom GBP                             5.25
#
#                                                  Unemployment_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                  3.7
# Shanghai_Composite China          CNY                                  5.2
# Nikkei_225         Japan          JPY                                  2.4
# DAX                Germany        EUR                                  3.1
# FTSE_100           United Kingdom GBP                                  4.2
#
#                                                  Exchange_Rate_USD  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                         1.00
# Shanghai_Composite China          CNY                         7.28
# Nikkei_225         Japan          JPY                       147.20
# DAX                Germany        EUR                         0.92
# FTSE_100           United Kingdom GBP                         0.78
#
#                                                  Currency_Change_YTD_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                    0.0
# Shanghai_Composite China          CNY                                    2.3
# Nikkei_225         Japan          JPY                                   -8.9
# DAX                Germany        EUR                                    1.8
# FTSE_100           United Kingdom GBP                                   -0.9
#
#                                                  ...  Commodity_Index  \
# Stock_Index        Country        Currency_Code  ...
# S&P_500            United States  USD            ...             1.12
# Shanghai_Composite China          CNY            ...             0.98
# Nikkei_225         Japan          JPY            ...             1.05
# DAX                Germany        EUR            ...             1.08
# FTSE_100           United Kingdom GBP            ...             1.06
#
#                                                  Oil_Price_USD_Barrel  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           77.85
# Shanghai_Composite China          CNY                           77.85
# Nikkei_225         Japan          JPY                           77.85
# DAX                Germany        EUR                           77.85
# FTSE_100           United Kingdom GBP                           77.85
#
#                                                  Gold_Price_USD_Ounce  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                          2487.5
# Shanghai_Composite China          CNY                          2487.5
# Nikkei_225         Japan          JPY                          2487.5
# DAX                Germany        EUR                          2487.5
# FTSE_100           United Kingdom GBP                          2487.5
#
#                                                  Bond_Yield_10Y_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              4.25
# Shanghai_Composite China          CNY                              2.15
# Nikkei_225         Japan          JPY                              0.89
# DAX                Germany        EUR                              2.31
# FTSE_100           United Kingdom GBP                              3.89
#
#                                                  Credit_Rating  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                      AAA
# Shanghai_Composite China          CNY                       A+
# Nikkei_225         Japan          JPY                       A+
# DAX                Germany        EUR                      AAA
# FTSE_100           United Kingdom GBP                       AA
#
#                                                  Political_Risk_Score  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             8.1
# Shanghai_Composite China          CNY                             6.7
# Nikkei_225         Japan          JPY                             8.4
# DAX                Germany        EUR                             8.7
# FTSE_100           United Kingdom GBP                             7.9
#
#                                                  Banking_Sector_Health  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           Strong
# Shanghai_Composite China          CNY                         Moderate
# Nikkei_225         Japan          JPY                           Strong
# DAX                Germany        EUR                           Strong
# FTSE_100           United Kingdom GBP                         Moderate
#
#                                                 Real_Estate_Index  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                       145.6
# Shanghai_Composite China          CNY                        98.7
# Nikkei_225         Japan          JPY                        89.3
# DAX                Germany        EUR                       112.4
# FTSE_100           United Kingdom GBP                        97.8
#
#                                                  Export_Growth_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              3.2
# Shanghai_Composite China          CNY                              8.9
# Nikkei_225         Japan          JPY                              5.1
# DAX                Germany        EUR                              2.1
# FTSE_100           United Kingdom GBP                              0.9
#
#                                                 Import_Growth_Percent
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             2.8
# Shanghai_Composite China          CNY                             6.1
# Nikkei_225         Japan          JPY                             4.7
# DAX                Germany        EUR                             1.8
# FTSE_100           United Kingdom GBP                             1.2
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Data Clearning Tasks
# 1. Check for null values
# 2. Apply the Pandas dropna() method to the whole dataframe
# 3. Dropping features with constant values: ["Date", "Oil_Price_USD_Barrel", "Gold_Price_USD_Ounce"]

# %%
gfd_df.isnull().head() #checking for missing values in the dataset - first 5 records shown
# Out:
#                                                   Date  Index_Value  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD            False        False
# Shanghai_Composite China          CNY            False        False
# Nikkei_225         Japan          JPY            False        False
# DAX                Germany        EUR            False        False
# FTSE_100           United Kingdom GBP            False        False
#
#                                                  Daily_Change_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           False
# Shanghai_Composite China          CNY                           False
# Nikkei_225         Japan          JPY                           False
# DAX                Germany        EUR                           False
# FTSE_100           United Kingdom GBP                           False
#
#                                                  Market_Cap_Trillion_USD  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              False
# Shanghai_Composite China          CNY                              False
# Nikkei_225         Japan          JPY                              False
# DAX                Germany        EUR                              False
# FTSE_100           United Kingdom GBP                              False
#
#                                                  GDP_Growth_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              False
# Shanghai_Composite China          CNY                              False
# Nikkei_225         Japan          JPY                              False
# DAX                Germany        EUR                              False
# FTSE_100           United Kingdom GBP                              False
#
#                                                  Inflation_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             False
# Shanghai_Composite China          CNY                             False
# Nikkei_225         Japan          JPY                             False
# DAX                Germany        EUR                             False
# FTSE_100           United Kingdom GBP                             False
#
#                                                  Interest_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                            False
# Shanghai_Composite China          CNY                            False
# Nikkei_225         Japan          JPY                            False
# DAX                Germany        EUR                            False
# FTSE_100           United Kingdom GBP                            False
#
#                                                  Unemployment_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                False
# Shanghai_Composite China          CNY                                False
# Nikkei_225         Japan          JPY                                False
# DAX                Germany        EUR                                False
# FTSE_100           United Kingdom GBP                                False
#
#                                                  Exchange_Rate_USD  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                        False
# Shanghai_Composite China          CNY                        False
# Nikkei_225         Japan          JPY                        False
# DAX                Germany        EUR                        False
# FTSE_100           United Kingdom GBP                        False
#
#                                                  Currency_Change_YTD_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                  False
# Shanghai_Composite China          CNY                                  False
# Nikkei_225         Japan          JPY                                  False
# DAX                Germany        EUR                                  False
# FTSE_100           United Kingdom GBP                                  False
#
#                                                  ...  Commodity_Index  \
# Stock_Index        Country        Currency_Code  ...
# S&P_500            United States  USD            ...            False
# Shanghai_Composite China          CNY            ...            False
# Nikkei_225         Japan          JPY            ...            False
# DAX                Germany        EUR            ...            False
# FTSE_100           United Kingdom GBP            ...            False
#
#                                                  Oil_Price_USD_Barrel  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           False
# Shanghai_Composite China          CNY                           False
# Nikkei_225         Japan          JPY                           False
# DAX                Germany        EUR                           False
# FTSE_100           United Kingdom GBP                           False
#
#                                                  Gold_Price_USD_Ounce  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           False
# Shanghai_Composite China          CNY                           False
# Nikkei_225         Japan          JPY                           False
# DAX                Germany        EUR                           False
# FTSE_100           United Kingdom GBP                           False
#
#                                                  Bond_Yield_10Y_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             False
# Shanghai_Composite China          CNY                             False
# Nikkei_225         Japan          JPY                             False
# DAX                Germany        EUR                             False
# FTSE_100           United Kingdom GBP                             False
#
#                                                  Credit_Rating  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                    False
# Shanghai_Composite China          CNY                    False
# Nikkei_225         Japan          JPY                    False
# DAX                Germany        EUR                    False
# FTSE_100           United Kingdom GBP                    False
#
#                                                  Political_Risk_Score  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           False
# Shanghai_Composite China          CNY                           False
# Nikkei_225         Japan          JPY                           False
# DAX                Germany        EUR                           False
# FTSE_100           United Kingdom GBP                           False
#
#                                                  Banking_Sector_Health  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                            False
# Shanghai_Composite China          CNY                            False
# Nikkei_225         Japan          JPY                            False
# DAX                Germany        EUR                            False
# FTSE_100           United Kingdom GBP                            False
#
#                                                  Real_Estate_Index  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                        False
# Shanghai_Composite China          CNY                        False
# Nikkei_225         Japan          JPY                        False
# DAX                Germany        EUR                        False
# FTSE_100           United Kingdom GBP                        False
#
#                                                  Export_Growth_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                            False
# Shanghai_Composite China          CNY                            False
# Nikkei_225         Japan          JPY                            False
# DAX                Germany        EUR                            False
# FTSE_100           United Kingdom GBP                            False
#
#                                                  Import_Growth_Percent
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                            False
# Shanghai_Composite China          CNY                            False
# Nikkei_225         Japan          JPY                            False
# DAX                Germany        EUR                            False
# FTSE_100           United Kingdom GBP                            False
#
# [5 rows x 23 columns]

# %%
gfd_df.isnull().sum() #checking total amount of missing values - all zeros
# Out:
# Date                                   0
# Index_Value                            0
# Daily_Change_Percent                   0
# Market_Cap_Trillion_USD                0
# GDP_Growth_Rate_Percent                0
# Inflation_Rate_Percent                 0
# Interest_Rate_Percent                  0
# Unemployment_Rate_Percent              0
# Exchange_Rate_USD                      0
# Currency_Change_YTD_Percent            0
# Government_Debt_GDP_Percent            0
# Current_Account_Balance_Billion_USD    0
# FDI_Inflow_Billion_USD                 0
# Commodity_Index                        0
# Oil_Price_USD_Barrel                   0
# Gold_Price_USD_Ounce                   0
# Bond_Yield_10Y_Percent                 0
# Credit_Rating                          0
# Political_Risk_Score                   0
# Banking_Sector_Health                  0
# Real_Estate_Index                      0
# Export_Growth_Percent                  0
# Import_Growth_Percent                  0
# dtype: int64

# %%
gfd_df.dropna() #dropping any features with 'NaN' values
# Out:
#                                                        Date  Index_Value  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD            2024-08-15       5437.2
# Shanghai_Composite China          CNY            2024-08-15       2891.6
# Nikkei_225         Japan          JPY            2024-08-15      36789.1
# DAX                Germany        EUR            2024-08-15      18234.5
# FTSE_100           United Kingdom GBP            2024-08-15       8156.3
# CAC_40             France         EUR            2024-08-15       7389.2
# Sensex             India          INR            2024-08-15      80456.7
# TSX                Canada         CAD            2024-08-15      22567.8
# Bovespa            Brazil         BRL            2024-08-15     129834.2
# ASX_200            Australia      AUD            2024-08-15       7923.4
# KOSPI              South Korea    KRW            2024-08-15       2634.5
# MOEX               Russia         RUB            2024-08-15       2789.1
# IPC                Mexico         MXN            2024-08-15      55234.6
# FTSE_MIB           Italy          EUR            2024-08-15      33456.7
# IBEX_35            Spain          EUR            2024-08-15      11123.8
# AEX                Netherlands    EUR            2024-08-15        889.3
# SMI                Switzerland    CHF            2024-08-15      12234.5
# OMX_Stockholm      Sweden         SEK            2024-08-15       2567.8
# OSE                Norway         NOK            2024-08-15       1345.6
# OMXC_20            Denmark        DKK            2024-08-15       2234.5
# STI                Singapore      SGD            2024-08-15       3456.7
# Hang_Seng          Hong Kong      HKD            2024-08-15      17234.5
# TAIEX              Taiwan         TWD            2024-08-15      22567.8
# JCI                Indonesia      IDR            2024-08-15       7234.5
# SET                Thailand       THB            2024-08-15       1567.8
# KLCI               Malaysia       MYR            2024-08-15       1634.5
# PSE                Philippines    PHP            2024-08-15       6789.1
# VN_Index           Vietnam        VND            2024-08-15       1234.5
# BIST_100           Turkey         TRY            2024-08-15      10567.8
# JSE                South Africa   ZAR            2024-08-15      75234.6
# EGX_30             Egypt          EGP            2024-08-15      25678.9
# NSE                Nigeria        NGN            2024-08-15      98765.4
# IPSA               Chile          CLP            2024-08-15       5678.9
# Merval             Argentina      ARS            2024-08-15    1567890.2
# COLCAP             Colombia       COP            2024-08-15       1234.5
# Lima_General       Peru           PEN            2024-08-15      23456.7
# ADX                UAE            AED            2024-08-15       9876.5
# Tadawul            Saudi Arabia   SAR            2024-08-15      12345.6
# TA_125             Israel         ILS            2024-08-15       1987.3
#
#                                                  Daily_Change_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                            0.34
# Shanghai_Composite China          CNY                           -0.82
# Nikkei_225         Japan          JPY                            1.24
# DAX                Germany        EUR                            0.67
# FTSE_100           United Kingdom GBP                           -0.15
# CAC_40             France         EUR                            0.28
# Sensex             India          INR                            0.89
# TSX                Canada         CAD                            0.45
# Bovespa            Brazil         BRL                            1.67
# ASX_200            Australia      AUD                            0.22
# KOSPI              South Korea    KRW                           -0.34
# MOEX               Russia         RUB                            0.78
# IPC                Mexico         MXN                            0.91
# FTSE_MIB           Italy          EUR                            0.34
# IBEX_35            Spain          EUR                            0.67
# AEX                Netherlands    EUR                            0.12
# SMI                Switzerland    CHF                            0.28
# OMX_Stockholm      Sweden         SEK                            0.45
# OSE                Norway         NOK                            0.67
# OMXC_20            Denmark        DKK                            0.23
# STI                Singapore      SGD                            0.56
# Hang_Seng          Hong Kong      HKD                           -1.23
# TAIEX              Taiwan         TWD                            0.78
# JCI                Indonesia      IDR                            0.45
# SET                Thailand       THB                            0.34
# KLCI               Malaysia       MYR                            0.67
# PSE                Philippines    PHP                            0.89
# VN_Index           Vietnam        VND                            1.23
# BIST_100           Turkey         TRY                            2.34
# JSE                South Africa   ZAR                            0.78
# EGX_30             Egypt          EGP                            1.45
# NSE                Nigeria        NGN                            2.10
# IPSA               Chile          CLP                            0.67
# Merval             Argentina      ARS                            3.45
# COLCAP             Colombia       COP                            0.89
# Lima_General       Peru           PEN                            1.12
# ADX                UAE            AED                            0.34
# Tadawul            Saudi Arabia   SAR                            0.56
# TA_125             Israel         ILS                           -0.78
#
#                                                  Market_Cap_Trillion_USD  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              51.20
# Shanghai_Composite China          CNY                              12.40
# Nikkei_225         Japan          JPY                               6.80
# DAX                Germany        EUR                               2.90
# FTSE_100           United Kingdom GBP                               3.10
# CAC_40             France         EUR                               3.00
# Sensex             India          INR                               4.30
# TSX                Canada         CAD                               2.80
# Bovespa            Brazil         BRL                               1.40
# ASX_200            Australia      AUD                               1.80
# KOSPI              South Korea    KRW                               1.90
# MOEX               Russia         RUB                               0.60
# IPC                Mexico         MXN                               0.70
# FTSE_MIB           Italy          EUR                               0.90
# IBEX_35            Spain          EUR                               0.80
# AEX                Netherlands    EUR                               1.10
# SMI                Switzerland    CHF                               1.80
# OMX_Stockholm      Sweden         SEK                               0.70
# OSE                Norway         NOK                               0.40
# OMXC_20            Denmark        DKK                               0.40
# STI                Singapore      SGD                               0.80
# Hang_Seng          Hong Kong      HKD                               4.20
# TAIEX              Taiwan         TWD                               2.10
# JCI                Indonesia      IDR                               0.70
# SET                Thailand       THB                               0.60
# KLCI               Malaysia       MYR                               0.50
# PSE                Philippines    PHP                               0.30
# VN_Index           Vietnam        VND                               0.30
# BIST_100           Turkey         TRY                               0.30
# JSE                South Africa   ZAR                               0.40
# EGX_30             Egypt          EGP                               0.03
# NSE                Nigeria        NGN                               0.04
# IPSA               Chile          CLP                               0.20
# Merval             Argentina      ARS                               0.05
# COLCAP             Colombia       COP                               0.10
# Lima_General       Peru           PEN                               0.08
# ADX                UAE            AED                               0.70
# Tadawul            Saudi Arabia   SAR                               2.80
# TA_125             Israel         ILS                               0.40
#
#                                                  GDP_Growth_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                2.8
# Shanghai_Composite China          CNY                                5.2
# Nikkei_225         Japan          JPY                                0.9
# DAX                Germany        EUR                                0.3
# FTSE_100           United Kingdom GBP                                1.1
# CAC_40             France         EUR                                1.3
# Sensex             India          INR                                6.8
# TSX                Canada         CAD                                2.9
# Bovespa            Brazil         BRL                                2.1
# ASX_200            Australia      AUD                                1.7
# KOSPI              South Korea    KRW                                3.1
# MOEX               Russia         RUB                               -1.9
# IPC                Mexico         MXN                                2.4
# FTSE_MIB           Italy          EUR                                0.7
# IBEX_35            Spain          EUR                                2.5
# AEX                Netherlands    EUR                                0.6
# SMI                Switzerland    CHF                                1.2
# OMX_Stockholm      Sweden         SEK                                0.8
# OSE                Norway         NOK                                2.1
# OMXC_20            Denmark        DKK                                1.8
# STI                Singapore      SGD                                2.6
# Hang_Seng          Hong Kong      HKD                                3.2
# TAIEX              Taiwan         TWD                                3.8
# JCI                Indonesia      IDR                                5.1
# SET                Thailand       THB                                2.9
# KLCI               Malaysia       MYR                                4.2
# PSE                Philippines    PHP                                5.8
# VN_Index           Vietnam        VND                                6.4
# BIST_100           Turkey         TRY                                3.1
# JSE                South Africa   ZAR                                0.9
# EGX_30             Egypt          EGP                                2.8
# NSE                Nigeria        NGN                                3.2
# IPSA               Chile          CLP                                2.4
# Merval             Argentina      ARS                               -1.6
# COLCAP             Colombia       COP                                1.2
# Lima_General       Peru           PEN                                2.8
# ADX                UAE            AED                                3.9
# Tadawul            Saudi Arabia   SAR                                1.1
# TA_125             Israel         ILS                                2.0
#
#                                                  Inflation_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                               2.9
# Shanghai_Composite China          CNY                               0.8
# Nikkei_225         Japan          JPY                               2.8
# DAX                Germany        EUR                               2.2
# FTSE_100           United Kingdom GBP                               2.0
# CAC_40             France         EUR                               2.3
# Sensex             India          INR                               4.9
# TSX                Canada         CAD                               2.8
# Bovespa            Brazil         BRL                               4.5
# ASX_200            Australia      AUD                               3.8
# KOSPI              South Korea    KRW                               2.4
# MOEX               Russia         RUB                               7.4
# IPC                Mexico         MXN                               4.7
# FTSE_MIB           Italy          EUR                               1.0
# IBEX_35            Spain          EUR                               3.2
# AEX                Netherlands    EUR                               1.1
# SMI                Switzerland    CHF                               1.4
# OMX_Stockholm      Sweden         SEK                               1.9
# OSE                Norway         NOK                               3.1
# OMXC_20            Denmark        DKK                               1.7
# STI                Singapore      SGD                               2.4
# Hang_Seng          Hong Kong      HKD                               1.8
# TAIEX              Taiwan         TWD                               2.1
# JCI                Indonesia      IDR                               2.8
# SET                Thailand       THB                               0.4
# KLCI               Malaysia       MYR                               2.0
# PSE                Philippines    PHP                               3.7
# VN_Index           Vietnam        VND                               4.1
# BIST_100           Turkey         TRY                              64.8
# JSE                South Africa   ZAR                               4.7
# EGX_30             Egypt          EGP                              33.1
# NSE                Nigeria        NGN                              21.8
# IPSA               Chile          CLP                               4.1
# Merval             Argentina      ARS                             211.4
# COLCAP             Colombia       COP                               7.2
# Lima_General       Peru           PEN                               2.8
# ADX                UAE            AED                               1.9
# Tadawul            Saudi Arabia   SAR                              -0.4
# TA_125             Israel         ILS                               2.3
#
#                                                  Interest_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             5.50
# Shanghai_Composite China          CNY                             3.10
# Nikkei_225         Japan          JPY                            -0.10
# DAX                Germany        EUR                             4.50
# FTSE_100           United Kingdom GBP                             5.25
# CAC_40             France         EUR                             4.50
# Sensex             India          INR                             6.50
# TSX                Canada         CAD                             4.75
# Bovespa            Brazil         BRL                            10.75
# ASX_200            Australia      AUD                             4.35
# KOSPI              South Korea    KRW                             3.50
# MOEX               Russia         RUB                            16.00
# IPC                Mexico         MXN                            11.00
# FTSE_MIB           Italy          EUR                             4.50
# IBEX_35            Spain          EUR                             4.50
# AEX                Netherlands    EUR                             4.50
# SMI                Switzerland    CHF                             1.25
# OMX_Stockholm      Sweden         SEK                             3.75
# OSE                Norway         NOK                             4.50
# OMXC_20            Denmark        DKK                             3.60
# STI                Singapore      SGD                             3.50
# Hang_Seng          Hong Kong      HKD                             5.75
# TAIEX              Taiwan         TWD                             1.50
# JCI                Indonesia      IDR                             6.00
# SET                Thailand       THB                             2.50
# KLCI               Malaysia       MYR                             3.00
# PSE                Philippines    PHP                             6.50
# VN_Index           Vietnam        VND                             4.50
# BIST_100           Turkey         TRY                            50.00
# JSE                South Africa   ZAR                             8.25
# EGX_30             Egypt          EGP                            27.25
# NSE                Nigeria        NGN                            18.75
# IPSA               Chile          CLP                             5.75
# Merval             Argentina      ARS                           133.00
# COLCAP             Colombia       COP                            10.75
# Lima_General       Peru           PEN                             5.75
# ADX                UAE            AED                             5.40
# Tadawul            Saudi Arabia   SAR                             6.00
# TA_125             Israel         ILS                             4.75
#
#                                                  Unemployment_Rate_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                  3.7
# Shanghai_Composite China          CNY                                  5.2
# Nikkei_225         Japan          JPY                                  2.4
# DAX                Germany        EUR                                  3.1
# FTSE_100           United Kingdom GBP                                  4.2
# CAC_40             France         EUR                                  7.4
# Sensex             India          INR                                  3.2
# TSX                Canada         CAD                                  6.1
# Bovespa            Brazil         BRL                                  7.8
# ASX_200            Australia      AUD                                  4.1
# KOSPI              South Korea    KRW                                  2.9
# MOEX               Russia         RUB                                  3.4
# IPC                Mexico         MXN                                  2.8
# FTSE_MIB           Italy          EUR                                  7.6
# IBEX_35            Spain          EUR                                 11.5
# AEX                Netherlands    EUR                                  3.6
# SMI                Switzerland    CHF                                  2.4
# OMX_Stockholm      Sweden         SEK                                  7.8
# OSE                Norway         NOK                                  3.4
# OMXC_20            Denmark        DKK                                  5.1
# STI                Singapore      SGD                                  2.1
# Hang_Seng          Hong Kong      HKD                                  2.8
# TAIEX              Taiwan         TWD                                  3.7
# JCI                Indonesia      IDR                                  5.4
# SET                Thailand       THB                                  1.2
# KLCI               Malaysia       MYR                                  3.4
# PSE                Philippines    PHP                                  5.9
# VN_Index           Vietnam        VND                                 12.3
# BIST_100           Turkey         TRY                                 10.5
# JSE                South Africa   ZAR                                 28.7
# EGX_30             Egypt          EGP                                  7.2
# NSE                Nigeria        NGN                                  5.1
# IPSA               Chile          CLP                                  8.8
# Merval             Argentina      ARS                                  6.2
# COLCAP             Colombia       COP                                 10.2
# Lima_General       Peru           PEN                                  6.4
# ADX                UAE            AED                                  2.8
# Tadawul            Saudi Arabia   SAR                                  5.8
# TA_125             Israel         ILS                                  3.4
#
#                                                  Exchange_Rate_USD  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                         1.00
# Shanghai_Composite China          CNY                         7.28
# Nikkei_225         Japan          JPY                       147.20
# DAX                Germany        EUR                         0.92
# FTSE_100           United Kingdom GBP                         0.78
# CAC_40             France         EUR                         0.92
# Sensex             India          INR                        83.70
# TSX                Canada         CAD                         1.37
# Bovespa            Brazil         BRL                         5.47
# ASX_200            Australia      AUD                         1.52
# KOSPI              South Korea    KRW                      1342.50
# MOEX               Russia         RUB                        91.20
# IPC                Mexico         MXN                        19.80
# FTSE_MIB           Italy          EUR                         0.92
# IBEX_35            Spain          EUR                         0.92
# AEX                Netherlands    EUR                         0.92
# SMI                Switzerland    CHF                         0.87
# OMX_Stockholm      Sweden         SEK                        10.90
# OSE                Norway         NOK                        11.20
# OMXC_20            Denmark        DKK                         6.86
# STI                Singapore      SGD                         1.35
# Hang_Seng          Hong Kong      HKD                         7.82
# TAIEX              Taiwan         TWD                        32.10
# JCI                Indonesia      IDR                     15487.00
# SET                Thailand       THB                        36.20
# KLCI               Malaysia       MYR                         4.67
# PSE                Philippines    PHP                        56.30
# VN_Index           Vietnam        VND                     24789.00
# BIST_100           Turkey         TRY                        33.70
# JSE                South Africa   ZAR                        18.20
# EGX_30             Egypt          EGP                        30.90
# NSE                Nigeria        NGN                      1567.00
# IPSA               Chile          CLP                       967.00
# Merval             Argentina      ARS                       945.00
# COLCAP             Colombia       COP                      4134.00
# Lima_General       Peru           PEN                         3.78
# ADX                UAE            AED                         3.67
# Tadawul            Saudi Arabia   SAR                         3.75
# TA_125             Israel         ILS                         3.68
#
#                                                  Currency_Change_YTD_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                                    0.0
# Shanghai_Composite China          CNY                                    2.3
# Nikkei_225         Japan          JPY                                   -8.9
# DAX                Germany        EUR                                    1.8
# FTSE_100           United Kingdom GBP                                   -0.9
# CAC_40             France         EUR                                    1.8
# Sensex             India          INR                                   -0.5
# TSX                Canada         CAD                                    4.2
# Bovespa            Brazil         BRL                                   -8.9
# ASX_200            Australia      AUD                                    5.6
# KOSPI              South Korea    KRW                                   -2.1
# MOEX               Russia         RUB                                  -15.6
# IPC                Mexico         MXN                                  -10.2
# FTSE_MIB           Italy          EUR                                    1.8
# IBEX_35            Spain          EUR                                    1.8
# AEX                Netherlands    EUR                                    1.8
# SMI                Switzerland    CHF                                    6.2
# OMX_Stockholm      Sweden         SEK                                   -4.7
# OSE                Norway         NOK                                    2.8
# OMXC_20            Denmark        DKK                                    1.9
# STI                Singapore      SGD                                    1.2
# Hang_Seng          Hong Kong      HKD                                    0.1
# TAIEX              Taiwan         TWD                                   -1.8
# JCI                Indonesia      IDR                                   -2.3
# SET                Thailand       THB                                    3.4
# KLCI               Malaysia       MYR                                   -6.7
# PSE                Philippines    PHP                                   -8.9
# VN_Index           Vietnam        VND                                   -3.4
# BIST_100           Turkey         TRY                                  -35.6
# JSE                South Africa   ZAR                                   -7.8
# EGX_30             Egypt          EGP                                  -49.7
# NSE                Nigeria        NGN                                  -68.9
# IPSA               Chile          CLP                                   -8.9
# Merval             Argentina      ARS                                  -89.7
# COLCAP             Colombia       COP                                  -18.9
# Lima_General       Peru           PEN                                   -6.7
# ADX                UAE            AED                                    0.0
# Tadawul            Saudi Arabia   SAR                                    0.0
# TA_125             Israel         ILS                                   -2.1
#
#                                                  ...  Commodity_Index  \
# Stock_Index        Country        Currency_Code  ...
# S&P_500            United States  USD            ...             1.12
# Shanghai_Composite China          CNY            ...             0.98
# Nikkei_225         Japan          JPY            ...             1.05
# DAX                Germany        EUR            ...             1.08
# FTSE_100           United Kingdom GBP            ...             1.06
# CAC_40             France         EUR            ...             1.08
# Sensex             India          INR            ...             1.15
# TSX                Canada         CAD            ...             1.09
# Bovespa            Brazil         BRL            ...             0.95
# ASX_200            Australia      AUD            ...             1.11
# KOSPI              South Korea    KRW            ...             1.02
# MOEX               Russia         RUB            ...             0.87
# IPC                Mexico         MXN            ...             0.89
# FTSE_MIB           Italy          EUR            ...             1.08
# IBEX_35            Spain          EUR            ...             1.08
# AEX                Netherlands    EUR            ...             1.08
# SMI                Switzerland    CHF            ...             1.13
# OMX_Stockholm      Sweden         SEK            ...             1.07
# OSE                Norway         NOK            ...             1.14
# OMXC_20            Denmark        DKK            ...             1.08
# STI                Singapore      SGD            ...             1.09
# Hang_Seng          Hong Kong      HKD            ...             0.98
# TAIEX              Taiwan         TWD            ...             1.04
# JCI                Indonesia      IDR            ...             0.94
# SET                Thailand       THB            ...             0.97
# KLCI               Malaysia       MYR            ...             0.91
# PSE                Philippines    PHP            ...             0.88
# VN_Index           Vietnam        VND            ...             0.85
# BIST_100           Turkey         TRY            ...             0.76
# JSE                South Africa   ZAR            ...             0.82
# EGX_30             Egypt          EGP            ...             0.71
# NSE                Nigeria        NGN            ...             0.68
# IPSA               Chile          CLP            ...             0.93
# Merval             Argentina      ARS            ...             0.45
# COLCAP             Colombia       COP            ...             0.78
# Lima_General       Peru           PEN            ...             0.91
# ADX                UAE            AED            ...             1.06
# Tadawul            Saudi Arabia   SAR            ...             1.18
# TA_125             Israel         ILS            ...             1.03
#
#                                                  Oil_Price_USD_Barrel  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           77.85
# Shanghai_Composite China          CNY                           77.85
# Nikkei_225         Japan          JPY                           77.85
# DAX                Germany        EUR                           77.85
# FTSE_100           United Kingdom GBP                           77.85
# CAC_40             France         EUR                           77.85
# Sensex             India          INR                           77.85
# TSX                Canada         CAD                           77.85
# Bovespa            Brazil         BRL                           77.85
# ASX_200            Australia      AUD                           77.85
# KOSPI              South Korea    KRW                           77.85
# MOEX               Russia         RUB                           77.85
# IPC                Mexico         MXN                           77.85
# FTSE_MIB           Italy          EUR                           77.85
# IBEX_35            Spain          EUR                           77.85
# AEX                Netherlands    EUR                           77.85
# SMI                Switzerland    CHF                           77.85
# OMX_Stockholm      Sweden         SEK                           77.85
# OSE                Norway         NOK                           77.85
# OMXC_20            Denmark        DKK                           77.85
# STI                Singapore      SGD                           77.85
# Hang_Seng          Hong Kong      HKD                           77.85
# TAIEX              Taiwan         TWD                           77.85
# JCI                Indonesia      IDR                           77.85
# SET                Thailand       THB                           77.85
# KLCI               Malaysia       MYR                           77.85
# PSE                Philippines    PHP                           77.85
# VN_Index           Vietnam        VND                           77.85
# BIST_100           Turkey         TRY                           77.85
# JSE                South Africa   ZAR                           77.85
# EGX_30             Egypt          EGP                           77.85
# NSE                Nigeria        NGN                           77.85
# IPSA               Chile          CLP                           77.85
# Merval             Argentina      ARS                           77.85
# COLCAP             Colombia       COP                           77.85
# Lima_General       Peru           PEN                           77.85
# ADX                UAE            AED                           77.85
# Tadawul            Saudi Arabia   SAR                           77.85
# TA_125             Israel         ILS                           77.85
#
#                                                  Gold_Price_USD_Ounce  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                          2487.5
# Shanghai_Composite China          CNY                          2487.5
# Nikkei_225         Japan          JPY                          2487.5
# DAX                Germany        EUR                          2487.5
# FTSE_100           United Kingdom GBP                          2487.5
# CAC_40             France         EUR                          2487.5
# Sensex             India          INR                          2487.5
# TSX                Canada         CAD                          2487.5
# Bovespa            Brazil         BRL                          2487.5
# ASX_200            Australia      AUD                          2487.5
# KOSPI              South Korea    KRW                          2487.5
# MOEX               Russia         RUB                          2487.5
# IPC                Mexico         MXN                          2487.5
# FTSE_MIB           Italy          EUR                          2487.5
# IBEX_35            Spain          EUR                          2487.5
# AEX                Netherlands    EUR                          2487.5
# SMI                Switzerland    CHF                          2487.5
# OMX_Stockholm      Sweden         SEK                          2487.5
# OSE                Norway         NOK                          2487.5
# OMXC_20            Denmark        DKK                          2487.5
# STI                Singapore      SGD                          2487.5
# Hang_Seng          Hong Kong      HKD                          2487.5
# TAIEX              Taiwan         TWD                          2487.5
# JCI                Indonesia      IDR                          2487.5
# SET                Thailand       THB                          2487.5
# KLCI               Malaysia       MYR                          2487.5
# PSE                Philippines    PHP                          2487.5
# VN_Index           Vietnam        VND                          2487.5
# BIST_100           Turkey         TRY                          2487.5
# JSE                South Africa   ZAR                          2487.5
# EGX_30             Egypt          EGP                          2487.5
# NSE                Nigeria        NGN                          2487.5
# IPSA               Chile          CLP                          2487.5
# Merval             Argentina      ARS                          2487.5
# COLCAP             Colombia       COP                          2487.5
# Lima_General       Peru           PEN                          2487.5
# ADX                UAE            AED                          2487.5
# Tadawul            Saudi Arabia   SAR                          2487.5
# TA_125             Israel         ILS                          2487.5
#
#                                                  Bond_Yield_10Y_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              4.25
# Shanghai_Composite China          CNY                              2.15
# Nikkei_225         Japan          JPY                              0.89
# DAX                Germany        EUR                              2.31
# FTSE_100           United Kingdom GBP                              3.89
# CAC_40             France         EUR                              2.95
# Sensex             India          INR                              7.04
# TSX                Canada         CAD                              3.42
# Bovespa            Brazil         BRL                             10.84
# ASX_200            Australia      AUD                              4.07
# KOSPI              South Korea    KRW                              3.28
# MOEX               Russia         RUB                             12.45
# IPC                Mexico         MXN                              9.12
# FTSE_MIB           Italy          EUR                              3.67
# IBEX_35            Spain          EUR                              3.21
# AEX                Netherlands    EUR                              2.78
# SMI                Switzerland    CHF                              0.68
# OMX_Stockholm      Sweden         SEK                              2.34
# OSE                Norway         NOK                              3.12
# OMXC_20            Denmark        DKK                              2.45
# STI                Singapore      SGD                              3.18
# Hang_Seng          Hong Kong      HKD                              3.89
# TAIEX              Taiwan         TWD                              1.23
# JCI                Indonesia      IDR                              7.12
# SET                Thailand       THB                              2.67
# KLCI               Malaysia       MYR                              3.78
# PSE                Philippines    PHP                              6.45
# VN_Index           Vietnam        VND                              2.89
# BIST_100           Turkey         TRY                             28.45
# JSE                South Africa   ZAR                             11.78
# EGX_30             Egypt          EGP                             19.45
# NSE                Nigeria        NGN                             14.67
# IPSA               Chile          CLP                              5.89
# Merval             Argentina      ARS                             89.45
# COLCAP             Colombia       COP                             12.34
# Lima_General       Peru           PEN                              6.78
# ADX                UAE            AED                              4.12
# Tadawul            Saudi Arabia   SAR                              4.23
# TA_125             Israel         ILS                              4.56
#
#                                                  Credit_Rating  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                      AAA
# Shanghai_Composite China          CNY                       A+
# Nikkei_225         Japan          JPY                       A+
# DAX                Germany        EUR                      AAA
# FTSE_100           United Kingdom GBP                       AA
# CAC_40             France         EUR                       AA
# Sensex             India          INR                     BBB-
# TSX                Canada         CAD                      AAA
# Bovespa            Brazil         BRL                      BB-
# ASX_200            Australia      AUD                      AAA
# KOSPI              South Korea    KRW                       AA
# MOEX               Russia         RUB                      BB+
# IPC                Mexico         MXN                      BBB
# FTSE_MIB           Italy          EUR                      BBB
# IBEX_35            Spain          EUR                        A
# AEX                Netherlands    EUR                      AAA
# SMI                Switzerland    CHF                      AAA
# OMX_Stockholm      Sweden         SEK                      AAA
# OSE                Norway         NOK                      AAA
# OMXC_20            Denmark        DKK                      AAA
# STI                Singapore      SGD                      AAA
# Hang_Seng          Hong Kong      HKD                      AA+
# TAIEX              Taiwan         TWD                       AA
# JCI                Indonesia      IDR                      BBB
# SET                Thailand       THB                     BBB+
# KLCI               Malaysia       MYR                       A-
# PSE                Philippines    PHP                     BBB+
# VN_Index           Vietnam        VND                      BB+
# BIST_100           Turkey         TRY                       B+
# JSE                South Africa   ZAR                      BB-
# EGX_30             Egypt          EGP                       B+
# NSE                Nigeria        NGN                       B-
# IPSA               Chile          CLP                        A
# Merval             Argentina      ARS                     CCC+
# COLCAP             Colombia       COP                      BB+
# Lima_General       Peru           PEN                     BBB+
# ADX                UAE            AED                       AA
# Tadawul            Saudi Arabia   SAR                       A-
# TA_125             Israel         ILS                       A+
#
#                                                  Political_Risk_Score  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             8.1
# Shanghai_Composite China          CNY                             6.7
# Nikkei_225         Japan          JPY                             8.4
# DAX                Germany        EUR                             8.7
# FTSE_100           United Kingdom GBP                             7.9
# CAC_40             France         EUR                             7.3
# Sensex             India          INR                             6.8
# TSX                Canada         CAD                             8.9
# Bovespa            Brazil         BRL                             5.4
# ASX_200            Australia      AUD                             8.6
# KOSPI              South Korea    KRW                             7.8
# MOEX               Russia         RUB                             3.2
# IPC                Mexico         MXN                             6.1
# FTSE_MIB           Italy          EUR                             7.1
# IBEX_35            Spain          EUR                             7.8
# AEX                Netherlands    EUR                             8.8
# SMI                Switzerland    CHF                             9.1
# OMX_Stockholm      Sweden         SEK                             8.9
# OSE                Norway         NOK                             9.0
# OMXC_20            Denmark        DKK                             8.9
# STI                Singapore      SGD                             8.7
# Hang_Seng          Hong Kong      HKD                             7.2
# TAIEX              Taiwan         TWD                             8.1
# JCI                Indonesia      IDR                             6.5
# SET                Thailand       THB                             7.1
# KLCI               Malaysia       MYR                             7.3
# PSE                Philippines    PHP                             6.8
# VN_Index           Vietnam        VND                             6.2
# BIST_100           Turkey         TRY                             4.8
# JSE                South Africa   ZAR                             5.9
# EGX_30             Egypt          EGP                             4.2
# NSE                Nigeria        NGN                             3.8
# IPSA               Chile          CLP                             7.8
# Merval             Argentina      ARS                             2.1
# COLCAP             Colombia       COP                             5.8
# Lima_General       Peru           PEN                             6.7
# ADX                UAE            AED                             8.2
# Tadawul            Saudi Arabia   SAR                             6.9
# TA_125             Israel         ILS                             6.8
#
#                                                  Banking_Sector_Health  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                           Strong
# Shanghai_Composite China          CNY                         Moderate
# Nikkei_225         Japan          JPY                           Strong
# DAX                Germany        EUR                           Strong
# FTSE_100           United Kingdom GBP                         Moderate
# CAC_40             France         EUR                         Moderate
# Sensex             India          INR                         Moderate
# TSX                Canada         CAD                           Strong
# Bovespa            Brazil         BRL                             Weak
# ASX_200            Australia      AUD                           Strong
# KOSPI              South Korea    KRW                           Strong
# MOEX               Russia         RUB                             Weak
# IPC                Mexico         MXN                         Moderate
# FTSE_MIB           Italy          EUR                         Moderate
# IBEX_35            Spain          EUR                         Moderate
# AEX                Netherlands    EUR                           Strong
# SMI                Switzerland    CHF                           Strong
# OMX_Stockholm      Sweden         SEK                           Strong
# OSE                Norway         NOK                           Strong
# OMXC_20            Denmark        DKK                           Strong
# STI                Singapore      SGD                           Strong
# Hang_Seng          Hong Kong      HKD                         Moderate
# TAIEX              Taiwan         TWD                           Strong
# JCI                Indonesia      IDR                         Moderate
# SET                Thailand       THB                         Moderate
# KLCI               Malaysia       MYR                         Moderate
# PSE                Philippines    PHP                         Moderate
# VN_Index           Vietnam        VND                         Moderate
# BIST_100           Turkey         TRY                             Weak
# JSE                South Africa   ZAR                             Weak
# EGX_30             Egypt          EGP                             Weak
# NSE                Nigeria        NGN                             Weak
# IPSA               Chile          CLP                         Moderate
# Merval             Argentina      ARS                             Weak
# COLCAP             Colombia       COP                         Moderate
# Lima_General       Peru           PEN                         Moderate
# ADX                UAE            AED                           Strong
# Tadawul            Saudi Arabia   SAR                         Moderate
# TA_125             Israel         ILS                         Moderate
#
#                                                 Real_Estate_Index  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                       145.6
# Shanghai_Composite China          CNY                        98.7
# Nikkei_225         Japan          JPY                        89.3
# DAX                Germany        EUR                       112.4
# FTSE_100           United Kingdom GBP                        97.8
# CAC_40             France         EUR                       103.2
# Sensex             India          INR                       134.8
# TSX                Canada         CAD                       126.7
# Bovespa            Brazil         BRL                        89.3
# ASX_200            Australia      AUD                       118.9
# KOSPI              South Korea    KRW                        95.6
# MOEX               Russia         RUB                        67.4
# IPC                Mexico         MXN                       102.3
# FTSE_MIB           Italy          EUR                        89.7
# IBEX_35            Spain          EUR                        98.3
# AEX                Netherlands    EUR                       134.5
# SMI                Switzerland    CHF                       142.6
# OMX_Stockholm      Sweden         SEK                       119.8
# OSE                Norway         NOK                       127.3
# OMXC_20            Denmark        DKK                       124.7
# STI                Singapore      SGD                        98.9
# Hang_Seng          Hong Kong      HKD                        87.6
# TAIEX              Taiwan         TWD                       112.4
# JCI                Indonesia      IDR                        89.7
# SET                Thailand       THB                        95.3
# KLCI               Malaysia       MYR                        87.9
# PSE                Philippines    PHP                        78.9
# VN_Index           Vietnam        VND                       123.4
# BIST_100           Turkey         TRY                        67.8
# JSE                South Africa   ZAR                        89.3
# EGX_30             Egypt          EGP                        56.7
# NSE                Nigeria        NGN                        78.9
# IPSA               Chile          CLP                        95.6
# Merval             Argentina      ARS                        34.5
# COLCAP             Colombia       COP                        87.3
# Lima_General       Peru           PEN                        98.7
# ADX                UAE            AED                       134.5
# Tadawul            Saudi Arabia   SAR                        98.7
# TA_125             Israel         ILS                        89.7
#
#                                                  Export_Growth_Percent  \
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                              3.2
# Shanghai_Composite China          CNY                              8.9
# Nikkei_225         Japan          JPY                              5.1
# DAX                Germany        EUR                              2.1
# FTSE_100           United Kingdom GBP                              0.9
# CAC_40             France         EUR                              1.8
# Sensex             India          INR                             13.2
# TSX                Canada         CAD                              4.1
# Bovespa            Brazil         BRL                              8.7
# ASX_200            Australia      AUD                              6.2
# KOSPI              South Korea    KRW                              9.1
# MOEX               Russia         RUB                             15.2
# IPC                Mexico         MXN                              7.9
# FTSE_MIB           Italy          EUR                              3.2
# IBEX_35            Spain          EUR                              4.1
# AEX                Netherlands    EUR                              2.8
# SMI                Switzerland    CHF                              1.9
# OMX_Stockholm      Sweden         SEK                              3.4
# OSE                Norway         NOK                              8.9
# OMXC_20            Denmark        DKK                              2.1
# STI                Singapore      SGD                             12.4
# Hang_Seng          Hong Kong      HKD                              6.7
# TAIEX              Taiwan         TWD                             15.2
# JCI                Indonesia      IDR                              8.9
# SET                Thailand       THB                              4.1
# KLCI               Malaysia       MYR                              6.7
# PSE                Philippines    PHP                              8.1
# VN_Index           Vietnam        VND                             12.8
# BIST_100           Turkey         TRY                              3.4
# JSE                South Africa   ZAR                              2.1
# EGX_30             Egypt          EGP                             12.3
# NSE                Nigeria        NGN                             23.4
# IPSA               Chile          CLP                              6.7
# Merval             Argentina      ARS                            -12.3
# COLCAP             Colombia       COP                              8.9
# Lima_General       Peru           PEN                              9.8
# ADX                UAE            AED                             23.4
# Tadawul            Saudi Arabia   SAR                             12.3
# TA_125             Israel         ILS                              5.6
#
#                                                 Import_Growth_Percent
# Stock_Index        Country        Currency_Code
# S&P_500            United States  USD                             2.8
# Shanghai_Composite China          CNY                             6.1
# Nikkei_225         Japan          JPY                             4.7
# DAX                Germany        EUR                             1.8
# FTSE_100           United Kingdom GBP                             1.2
# CAC_40             France         EUR                             2.1
# Sensex             India          INR                            10.9
# TSX                Canada         CAD                             3.8
# Bovespa            Brazil         BRL                             6.9
# ASX_200            Australia      AUD                             5.4
# KOSPI              South Korea    KRW                             7.8
# MOEX               Russia         RUB                            18.7
# IPC                Mexico         MXN                             8.2
# FTSE_MIB           Italy          EUR                             2.9
# IBEX_35            Spain          EUR                             3.7
# AEX                Netherlands    EUR                             2.4
# SMI                Switzerland    CHF                             2.1
# OMX_Stockholm      Sweden         SEK                             2.9
# OSE                Norway         NOK                             6.7
# OMXC_20            Denmark        DKK                             1.8
# STI                Singapore      SGD                            11.7
# Hang_Seng          Hong Kong      HKD                             5.9
# TAIEX              Taiwan         TWD                            13.8
# JCI                Indonesia      IDR                             7.3
# SET                Thailand       THB                             3.8
# KLCI               Malaysia       MYR                             5.9
# PSE                Philippines    PHP                             7.4
# VN_Index           Vietnam        VND                            14.2
# BIST_100           Turkey         TRY                             8.9
# JSE                South Africa   ZAR                             1.8
# EGX_30             Egypt          EGP                            23.4
# NSE                Nigeria        NGN                            34.5
# IPSA               Chile          CLP                             5.2
# Merval             Argentina      ARS                            15.6
# COLCAP             Colombia       COP                             7.1
# Lima_General       Peru           PEN                             8.2
# ADX                UAE            AED                            18.9
# Tadawul            Saudi Arabia   SAR                             8.9
# TA_125             Israel         ILS                             4.2
#
# [39 rows x 23 columns]

# %%
gfd_df = gfd_df.drop(['Date', 'Oil_Price_USD_Barrel', 'Gold_Price_USD_Ounce'], axis=1) #dropping features with constant values

# %%
gfd_df.info() #check to see if above features have been dropped
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 39 entries, ('S&P_500', 'United States', 'USD') to ('TA_125', 'Israel', 'ILS')
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Index_Value                          39 non-null     float64
#  1   Daily_Change_Percent                 39 non-null     float64
#  2   Market_Cap_Trillion_USD              39 non-null     float64
#  3   GDP_Growth_Rate_Percent              39 non-null     float64
#  4   Inflation_Rate_Percent               39 non-null     float64
#  5   Interest_Rate_Percent                39 non-null     float64
#  6   Unemployment_Rate_Percent            39 non-null     float64
#  7   Exchange_Rate_USD                    39 non-null     float64
#  8   Currency_Change_YTD_Percent          39 non-null     float64
#  9   Government_Debt_GDP_Percent          39 non-null     float64
#  10  Current_Account_Balance_Billion_USD  39 non-null     float64
#  11  FDI_Inflow_Billion_USD               39 non-null     float64
#  12  Commodity_Index                      39 non-null     float64
#  13  Bond_Yield_10Y_Percent               39 non-null     float64
#  14  Credit_Rating                        39 non-null     category
#  15  Political_Risk_Score                 39 non-null     float64
#  16  Banking_Sector_Health                39 non-null     category
#  17  Real_Estate_Index                    39 non-null     float64
#  18  Export_Growth_Percent                39 non-null     float64
#  19  Import_Growth_Percent                39 non-null     float64
# dtypes: category(2), float64(18)
# memory usage: 10.6+ KB

# %% [markdown]
# ### Finally, saving the clean data frame as a new file ready for the feature enrichment process

# %%
gfd_df.to_csv('global_finance_data_cleaned.csv', index=True) #making sure the index features are included in new file
